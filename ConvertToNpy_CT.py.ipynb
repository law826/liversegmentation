# %%
# some imports
import os
from skimage.draw import polygon
from skimage.transform import resize
from scipy import interpolate
import nibabel as nib
import pydicom
import numpy as np
from glob import glob
import xmltodict
from ast import literal_eval
from matplotlib import pyplot as plt
from operator import itemgetter
from natsort import natsorted
from VisTools import multi_slice_viewer0, mask_viewer0
import zipfile
import shutil
from pillow_handler import get_pixeldata
import sys
sys.path.append('/usr/local/Cellar/gdcm/2.8.9/lib/python3.7/site-packages')
import gdcm

# %%
# root_dir = '/Volumes/Seagate/radiology/research/liversegmentation/CT/troubleshoot'
unzipfile = False
root_dir = '/Volumes/Seagate/radiology/research/liversegmentation/CT/test'
# root_dir = 
# root_dir = '/Volumes/Seagate/radiology/research/liversegmentation/CT/done_by_steve_split'
# root_dir = '/Volumes/Seagate/radiology/research/liversegmentation/SSFSE_JKB01_165'
# root_dir = '/Volumes/Seagate/radiology/research/liversegmentation/temp_run'

# %%
# set desired in-plane dimensions
new_dims = (512,512)

# turn plotting on or off
display_plots = True

# set z-axis orientation to normal or reversed
z_reversed = True

# %%
# function for loading coordinate data from ROI
def GetROIcoords(roi):
    # get index of ROI
    ind = int(roi['integer'][1])
    # get coordinate data of ROI
    x = roi['array']['dict']['array'][1]['string']
    # convert string coordinates to tuples
    coords = [literal_eval(coord) for coord in x]
    # parse out x and y and make closed loop
    x = [i[0] for i in coords] + [coords[0][0]]
    y = [i[1] for i in coords] + [coords[0][1]]
    # apply parametric spline interpolation
    tck, _ = interpolate.splprep([x,y], s=0, per=True)
    x, y = interpolate.splev(np.linspace(0,1,500), tck)
    return ind,x,y

# %%
# function for loading in images and mask given file paths
def GetImageMaskData(file_xml,dcm_files,new_dims):
    # open up xml file and grab the list of ROIs
    with open(file_xml) as f:
        doc = xmltodict.parse(f.read())
    roi_list = doc['plist']['dict']['array']['dict']
    # parse out the image shape
    # imshape = (int(roi_list[0]['integer'][0]),int(roi_list[0]['integer'][3]))
    # get slice locations of all dicoms
    locs = [(d,float(pydicom.dcmread(d).SliceLocation)) for d in dcm_files]
    # sort
    locs.sort(key=itemgetter(1))
    dcm_files = [l[0] for l in locs]
    # load dicoms into volume
    # import pdb; pdb.set_trace()
    # dicom_dataset = dcm.dcmread(dcm_files[1])
    # pixel_data_element = get_pixeldata(dicom_dataset)

    import pdb; pdb.set_trace()
    image_volume = np.stack([pydicom.dcmread(d).pixel_array for d in dcm_files])

    #.astype(np.float)


    # window level
    dicom_img = pydicom.dcmread(dcm_files[0])
    window_center=50.0
    window_width=400.0
    jpg_scale = 255.0
    lower_limit = window_center-(window_width/2)
    upper_limit = window_center+(window_width/2)

    # dicom_img = dicom.read_file(dcm_file_path, force=True)
    img = image_volume

    rescale_slope = float(dicom_img.RescaleSlope)
    rescale_intercept = float(dicom_img.RescaleIntercept)
    hounsfield_img = (img * rescale_slope) + rescale_intercept

    clipped_img = np.clip(hounsfield_img, lower_limit, upper_limit)

    windowed_img = (clipped_img / window_width) - (lower_limit / window_width)

    # # normalize by image
    for i in range(windowed_img.shape[0]):
        im = windowed_img[i]
        im /= np.max(im)
        windowed_img[i] = im
    # resample image volume to desired dimensions
    output_shape = (windowed_img.shape[0],new_dims[0],new_dims[1])
    im_vol = resize(windowed_img,output_shape)
    # convert contours into masks
    # make empty mask
    mask = np.zeros(output_shape)
    # import pdb; pdb.set_trace()
    # calculate rescaling factor in each dimension
    x_scale = float(new_dims[1])/float(windowed_img.shape[2])
    y_scale = float(new_dims[0])/float(windowed_img.shape[1])
    # loop over ROIs
    for cur_roi in roi_list:
        ind,x,y = GetROIcoords(cur_roi)
        xs = [d*x_scale for d in x]
        ys = [d*y_scale for d in y]
        rr, cc = polygon(ys, xs)
        # one of these two lines determines
        #  z-axis orientation of the mask
        if z_reversed:
            zind = ind
        else:
            zind = mask.shape[0]-ind-1
        mask[zind,rr, cc] = 1
    return im_vol,mask

# %%
# set current working directory


os.chdir(os.path.join(root_dir))
output_dir = os.path.join(root_dir, 'output')

if not os.path.exists(output_dir):
    os.makedirs(output_dir)

patient_dirs = glob(os.path.join(root_dir,'*'))

# take off the first elements which is a spreadsheet
# patient_dirs.pop(0)

# %%
for patient_dir in patient_dirs:
    phase_dirs = glob(os.path.join(patient_dir,'*'))

    for phase_dir in phase_dirs:
        if unzipfile:
            path_to_zip_file = glob(os.path.join(phase_dir, '*.zip'))
            path_to_zip_file = path_to_zip_file[0]
            directory_to_extract_to = path_to_zip_file.replace('.zip', '')

            zip_ref = zipfile.ZipFile(path_to_zip_file, 'r')
            zip_ref.extractall(directory_to_extract_to)
            zip_ref.close()

            # delete resource fork: weird os x thing
            resource_fork_path = os.path.join(directory_to_extract_to, '__MACOSX')

            if os.path.exists(resource_fork_path):
                shutil.rmtree(resource_fork_path)

        # set data directory
        # phase_dir = os.path.join(os.getcwd(),'SampleData')
        # set output directory
        # output_dir = os.path.join(os.getcwd(),'NPYdata')
        # os.makedirs(output_dir, exist_ok=True)


        # subject index
        cur_subj = 0

        # find xml files
        xml_files = natsorted(glob(os.path.join(phase_dir, "*.xml")))
        # grab current subject file
        cur_xml_file = xml_files[cur_subj]

        # find dicom files
        temp_dir = glob(os.path.join(phase_dir,'*',''))

        #### Comment out the below for some of the files.
        temp_dir = glob(os.path.join(temp_dir[0],'*',''))
        temp_dir = glob(os.path.join(temp_dir[0],'*',''))
        #### End


        dicom_dirs = natsorted(glob(os.path.join(temp_dir[0],'*','')))
        # get current subject set of dicom files
        cur_dcm_files = glob(os.path.join(dicom_dirs[cur_subj], "*.dcm"))


        # # load in images and mask
        imvol, maskvol = GetImageMaskData(cur_xml_file,cur_dcm_files,new_dims)

        # # display
        if display_plots:
            mask_viewer0(imvol,.5*maskvol)
            plt.show()

        # save arrays as .npy
        image_name = os.path.join(output_dir,'input{:04d}.npy'.format(cur_subj))
        target_name = os.path.join(output_dir,'target{:04d}.npy'.format(cur_subj))
        subject_basename = os.path.basename(os.path.normpath(phase_dir))
        image_name = os.path.join(output_dir,'input_' + subject_basename)
        target_name = os.path.join(output_dir,'target_' + subject_basename)
        np.save(image_name,imvol)
        np.save(target_name,maskvol)

        print(subject_basename)
# Out:
# > <ipython-input-15-46f9f2100b2a>(20)GetImageMaskData()
# -> image_volume = np.stack([pydicom.dcmread(d).pixel_array for d in dcm_files])
# (Pdb) pydicom.dcmread(d)
# *** NameError: name 'd' is not defined
# (Pdb) pydicom.dcmread(dcm_files[0])
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'AXIAL', 'CT_SOM5 SPI']
# (0008, 0016) SOP Class UID                       UI: CT Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.3.6.1.4.1.19291.2.1.3.156201134602011655591730892554885
# (0008, 0020) Study Date                          DA: '20000101'
# (0008, 0021) Series Date                         DA: '20000101'
# (0008, 0022) Acquisition Date                    DA: '20000101'
# (0008, 0023) Content Date                        DA: '20000101'
# (0008, 002a) Acquisition DateTime                DT: '20140206171004.663000'
# (0008, 0030) Study Time                          TM: '170152.894000'
# (0008, 0031) Series Time                         TM: '171411.681000'
# (0008, 0032) Acquisition Time                    TM: '171004.663000'
# (0008, 0033) Content Time                        TM: '171004.663000'
# (0008, 0050) Accession Number                    SH: 'AA474116'
# (0008, 0060) Modality                            CS: 'CT'
# (0008, 0070) Manufacturer                        LO: 'SIEMENS'
# (0008, 0080) Institution Name                    LO: 'DUKE UNIVERSITY MEDICAL CENTER  DMP CT3'
# (0008, 0081) Institution Address                 ST: 'Duke Medicine Circle\r\nDurham 400-434998\r\nDistrict\r\nUS'
# (0008, 0090) Referring Physician's Name          PN: 'BERG^CARL L'
# (0008, 1010) Station Name                        SH: 'CTAWP73718'
# (0008, 1030) Study Description                   LO: 'Abdomen^11_CIRRHOSIS_CAP (Adult)'
# (0008, 1032)  Procedure Code Sequence   1 item(s) ----
#    (0008, 0100) Code Value                          SH: 'IMG105612'
#    (0008, 0102) Coding Scheme Designator            SH: 'CCG_CSTemp'
#    (0008, 0104) Code Meaning                        LO: 'CT CIRRHOSIS PROTOCOL INC CHEST W MIPS AND ABD PEL W'
#    ---------
# (0008, 103e) Series Description                  LO: 'BODYAXW  5.0  I31f  2'
# (0008, 1048) Physician(s) of Record              PN: 'BERG^CARL^LANSING^^'
# (0008, 1050) Performing Physician's Name         PN: ''
# (0008, 1070) Operators' Name                     PN: 'AFH'
# (0008, 1080) Admitting Diagnoses Description     LO: 'AAAA474116'
# (0008, 1090) Manufacturer's Model Name           LO: 'SOMATOM Definition Flash'
# (0008, 1110)  Referenced Study Sequence   1 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: 1.2.840.100008.3.1.2.3.1
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.2.840.113619.2.182.10808617745213.1391719757.1142915
#    ---------
# (0008, 1140)  Referenced Image Sequence   1 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.73718.30000014020612122504200001323
#    ---------
# (0008, 2111) Derivation Description              ST: 'LossLess compression with JPEG 2K, compression ratio 2.8702'
# (0008, 2112)  Source Image Sequence   1 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: 1.3.12.2.1107.5.9.1
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.73718.30000014020612424534400000090
#    ---------
# (0008, 3010) Irradiation Event UID               UI: 1.3.12.2.1107.5.1.4.73718.30000014020612424534400000090
# (0008, 9215)  Derivation Code Sequence   1 item(s) ----
#    (0008, 0100) Code Value                          SH: '121327'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Full fidelity image, uncompressed or lossless compressed'
#    ---------
# (0009, 0010) Private Creator                     LO: 'SIEMENS CT VA1 DUMMY'
# (0009, 0011) Private Creator                     LO: 'GEIIS'
# (0010, 0010) Patient's Name                      PN: 'LRML_0085'
# (0010, 0021) Issuer of Patient ID                LO: '001SE8:20050423:211030546:052024'
# (0010, 0030) Patient's Birth Date                DA: '19521202'
# (0010, 0040) Patient's Sex                       CS: 'M'
# (0010, 1000) Other Patient IDs                   LO: 'null null'
# (0010, 1010) Patient's Age                       AS: '061Y'
# (0010, 2154) Patient's Telephone Numbers         SH: '(704)246-6465'
# (0010, 2160) Ethnic Group                        SH: 'W'
# (0010, 21c0) Pregnancy Status                    US: 4
# (0018, 0010) Contrast/Bolus Agent                LO: 'ISOVUE 300'
# (0018, 0015) Body Part Examined                  CS: 'ABDOMEN'
# (0018, 0050) Slice Thickness                     DS: "5"
# (0018, 0060) KVP                                 DS: "120"
# (0018, 0090) Data Collection Diameter            DS: "500"
# (0018, 1000) Device Serial Number                LO: '73718'
# (0018, 1020) Software Version(s)                 LO: 'syngo CT 2012B'
# (0018, 1030) Protocol Name                       LO: '11_CIRRHOSIS_CAP'
# (0018, 1041) Contrast/Bolus Volume               DS: "175"
# (0018, 1042) Contrast/Bolus Start Time           TM: '170933.367010'
# (0018, 1043) Contrast/Bolus Stop Time            TM: '171008.367021'
# (0018, 1044) Contrast/Bolus Total Dose           DS: "175"
# (0018, 1046) Contrast Flow Rate                  DS: "5"
# (0018, 1047) Contrast Flow Duration              DS: "35"
# (0018, 1049) Contrast/Bolus Ingredient Concentra DS: "0"
# (0018, 1100) Reconstruction Diameter             DS: "420"
# (0018, 1110) Distance Source to Detector         DS: "1085.6"
# (0018, 1111) Distance Source to Patient          DS: "595"
# (0018, 1120) Gantry/Detector Tilt                DS: "0"
# (0018, 1130) Table Height                        DS: "190"
# (0018, 1140) Rotation Direction                  CS: 'CW'
# (0018, 1150) Exposure Time                       IS: "500"
# (0018, 1151) X-Ray Tube Current                  IS: "149"
# (0018, 1152) Exposure                            IS: "93"
# (0018, 1160) Filter Type                         SH: 'WEDGE_3'
# (0018, 1170) Generator Power                     IS: "29"
# (0018, 1190) Focal Spot(s)                       DS: "1.2"
# (0018, 1200) Date of Last Calibration            DA: '20140206'
# (0018, 1201) Time of Last Calibration            TM: ''
# (0018, 1210) Convolution Kernel                  SH: ['I31f', '2']
# (0018, 5100) Patient Position                    CS: 'FFS'
# (0018, 9306) Single Collimation Width            FD: 0.6
# (0018, 9307) Total Collimation Width             FD: 38.4
# (0018, 9309) Table Speed                         FD: 61.4
# (0018, 9310) Table Feed per Rotation             FD: 30.7
# (0018, 9311) Spiral Pitch Factor                 FD: 0.8
# (0018, 9313) Data Collection Center (Patient)    FD: [0.41015625, -189.58984375, -140.1]
# (0018, 9318) Reconstruction Target Center (Patie FD: [0.41015625, -189.58984375, -140.1]
# (0018, 9323) Exposure Modulation Type            CS: 'XYZ_EC'
# (0018, 9324) Estimated Dose Saving               FD: 32.0533
# (0018, 9345) CTDIvol                             FD: 6.286994720521172
# (0018, 9346)  CTDI Phantom Type Code Sequence   1 item(s) ----
#    (0008, 0100) Code Value                          SH: '113691'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'IEC Body Dosimetry Phantom'
#    ---------
# (0018, 9352) Calcium Scoring Mass Factor Device  FL: [0.7429999709129333, 0.7789999842643738, 0.8119999766349792]
# (0019, 0010) Private Creator                     LO: 'SIEMENS CT VA0  COAD'
# (0019, 1090) [Osteo Offset]                      DS: "0"
# (0019, 1092) [Osteo Regression Line Slope]       DS: "0.9179"
# (0019, 1093) [Osteo Regression Line Intercept]   DS: "-0.21"
# (0019, 1096) [Osteo Phantom Number]              IS: "0"
# (0019, 10b0) [Feed per Rotation]                 DS: "30.7"
# (0020, 000d) Study Instance UID                  UI: 1.3.6.1.4.1.19291.2.1.1.156201134602011655591730817354547
# (0020, 000e) Series Instance UID                 UI: 1.3.6.1.4.1.19291.2.1.2.156201134602011655591730892554884
# (0020, 0010) Study ID                            SH: 'AA474116'
# (0020, 0011) Series Number                       IS: "5"
# (0020, 0012) Acquisition Number                  IS: "9"
# (0020, 0013) Instance Number                     IS: "1"
# (0020, 0032) Image Position (Patient)            DS: ['-209.58984375', '-399.58984375', '-140.1']
# (0020, 0037) Image Orientation (Patient)         DS: ['1', '0', '0', '0', '1', '0']
# (0020, 0052) Frame of Reference UID              UI: 1.3.12.2.1107.5.1.4.73718.30000014020612424534400000085
# (0020, 1040) Position Reference Indicator        LO: ''
# (0020, 1041) Slice Location                      DS: "140.1"
# (0020, 4000) Image Comments                      LT: ''
# (0021, 0010) Private Creator                     LO: 'SIEMENS MED'
# (0021, 1011) [Target]                            DS: ['0', '0']
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 512
# (0028, 0011) Columns                             US: 512
# (0028, 0030) Pixel Spacing                       DS: ['0.8203125', '0.8203125']
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 12
# (0028, 0102) High Bit                            US: 11
# (0028, 0103) Pixel Representation                US: 0
# (0028, 0106) Smallest Image Pixel Value          US: 0
# (0028, 0107) Largest Image Pixel Value           US: 2032
# (0028, 1050) Window Center                       DS: ['40', '-600']
# (0028, 1051) Window Width                        DS: ['350', '1500']
# (0028, 1052) Rescale Intercept                   DS: "-1024"
# (0028, 1053) Rescale Slope                       DS: "1"
# (0028, 1054) Rescale Type                        LO: 'HU'
# (0028, 1055) Window Center & Width Explanation   LO: ['WINDOW1', 'WINDOW2']
# (0029, 0010) Private Creator                     LO: 'SIEMENS CSA HEADER'
# (0029, 0011) Private Creator                     LO: 'SIEMENS MEDCOM HEADER'
# (0029, 1008) [CSA Image Header Type]             CS: 'SOM 5'
# (0029, 1009) [CSA Image Header Version]          LO: 'VA10A 971201'
# (0029, 1010) [CSA Image Header Info]             OB: Array of 1326 bytes
# (0029, 1140)  [Application Header Sequence]   2 item(s) ----
#    (0029, 0010) Private Creator                     LO: 'SIEMENS MEDCOM HEADER'
#    (0029, 1041) [Application Header Type]           CS: 'VIA_CARE_KV_WIND'
#    (0029, 1042) [Application Header ID]             LO: 'ORIG WINDOW VALUES FROM CAREKV'
#    (0029, 1043) [Application Header Version]        LO: 'V1 20120914'
#    (0029, 1044) [Application Header Info]           OB: b'4\x000\x00#\x003\x005\x000\x00\x00\x00'
#    ---------
#    (0029, 0010) Private Creator                     LO: 'SIEMENS MEDCOM HEADER'
#    (0029, 1041) [Application Header Type]           CS: 'SOM 5 TPOS'
#    (0029, 1042) [Application Header ID]             LO: 'SOM 5 NULLPOSITION'
#    (0029, 1043) [Application Header Version]        LO: 'VB10A 20030626'
#    (0029, 1044) [Application Header Info]           OB: b'-000019200\x00\x00'
#    ---------
# (0032, 1032) Requesting Physician                PN: 'BERG^CARL^LANSING^^'
# (0032, 1033) Requesting Service                  LO: 'Unspecified'
# (0032, 1060) Requested Procedure Description     LO: 'CT CIRRHOSIS PROTOCOL INC CHEST W MIPS AND ABD PEL W'
# (0032, 1064)  Requested Procedure Code Sequence   1 item(s) ----
#    (0008, 0100) Code Value                          SH: 'IMG105612'
#    (0008, 0102) Coding Scheme Designator            SH: 'CCG_CSTemp'
#    (0008, 0104) Code Meaning                        LO: 'CT CIRRHOSIS PROTOCOL INC CHEST W MIPS AND ABD PEL W'
#    ---------
# (0040, 0275)  Request Attributes Sequence   1 item(s) ----
#    (0040, 1001) Requested Procedure ID              SH: 'AA474116'
#    ---------
# (0040, 2017) Filler Order Number / Imaging Servi LO: '171739832'
# (0040, 3001) Confidentiality Constraint on Patie LO: 'N'
# (0903, 0010) Private Creator                     LO: 'GEIIS PACS'
# (0903, 1010) [Reject Image Flag]                 US: 0
# (0903, 1011) [Significant Flag]                  US: 0
# (0903, 1012) [Confidential Flag]                 US: 0
# (0905, 0010) Private Creator                     LO: 'GEIIS'
# (0905, 1030) [Assigning Authority For Patient ID LO: '001SE8:20050423:211030546:052024'
# (7fd1, 0010) Private Creator                     LO: 'GEIIS'
# (7fd1, 1010) [GE IIS Compression ID]             UL: 0
# (7fe0, 0010) Pixel Data                          OB: Array of 182684 bytes

# %%
phase_dir
