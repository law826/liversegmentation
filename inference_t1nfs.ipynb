# %%
# some imports
import os
import numpy as np
np.random.seed(seed=1)
from glob import glob
from matplotlib import pyplot as plt
# %matplotlib notebook
from natsort import natsorted
import keras
from keras.optimizers import Adam

# import custom functions and viewing tools
from VisTools import multi_slice_viewer0, mask_viewer0
from KerasModel import BlockModel, dice_coef_loss, CalcVolumes
# Out:
# Using TensorFlow backend.

# %%
#~# some parameters to set for inference #~#
# model version to use
model_version = 3
model_weights_path = os.path.join(os.getcwd(),
                                  'BestModelWeights_v{:02d}.h5'.format(model_version))
# set data directory
data_dir = os.path.join('/Volumes/Seagate/radiology/research/liversegmentation/nonfinal_new_sequence_t1nfs/output')

# %%
# find data in directory
all_inputs = natsorted(glob(os.path.join(data_dir,"input*.npy")))
all_targets = natsorted(glob(os.path.join(data_dir,"target*.npy")))
print('{} subjects found'.format(len(all_inputs)))
print('Loading data...')
inputs = np.concatenate([np.load(f) for f in all_inputs])[...,np.newaxis]
targets = np.concatenate([np.load(f) for f in all_targets])[...,np.newaxis]
print("Data loaded")
# Out:
# 17 subjects found
# Loading data...
# Data loaded

# %%
# prepare model
model = BlockModel(inputs.shape,filt_num=16,numBlocks=4)
model.compile(optimizer=Adam(), loss=dice_coef_loss)

# load best weights
model.load_weights(model_weights_path)
# evaluate on test data
print('Evaluating data...')
score = model.evaluate(inputs,targets,verbose=1)
print("Test Dice score is {:.03f}".format(1-score))
# Out:
# Evaluating data...
# 868/868 [==============================] - 1312s 2s/step
# Test Dice score is 0.605

# %%
# display some results
print('Generating masks...')
output = model.predict(inputs,batch_size=16)
mask_viewer0(inputs[...,0],targets[...,0],output[...,0],name='Test Results')
plt.show()
# Out:
# Generating masks...

# %%
# set voxel dimensions (in cm)
sx = .7
sy = .1
sz = .2
vox_vol = sx*sy*sz
# loop over all subjects
results = []
for inp_file,targ_file in zip(all_inputs,all_targets):
    # run function to perform calculations
    calc,truth = CalcVolumes(inp_file,targ_file,vox_vol,model)
    results.append((calc,truth))
    # display result
    print('---------------------------------------')
    print(inp_file[-30:])
    print("The calculated volume is {:.02f} cm^3".format(calc))
    print("The actual volume is {:.02f} cm^3".format(truth))
# Out:
# ---------------------------------------
# input_JKB01_001_01_A_SSFSE.npy
# The calculated volume is 5669.73 cm^3
# The actual volume is 5224.31 cm^3
# ---------------------------------------
# input_JKB01_001_01_B_SSFSE.npy
# The calculated volume is 6205.02 cm^3
# The actual volume is 5811.29 cm^3
# ---------------------------------------
# input_JKB01_001_01_C_SSFSE.npy
# The calculated volume is 6796.20 cm^3
# The actual volume is 6214.50 cm^3
# ---------------------------------------
# input_JKB01_001_03_A_SSFSE.npy
# The calculated volume is 2643.45 cm^3
# The actual volume is 2731.25 cm^3
# ---------------------------------------
# input_JKB01_001_03_B_SSFSE.npy
# The calculated volume is 2825.28 cm^3
# The actual volume is 2846.97 cm^3
# ---------------------------------------
# input_JKB01_001_03_C_SSFSE.npy
# The calculated volume is 2756.31 cm^3
# The actual volume is 2712.21 cm^3
# ---------------------------------------
# input_JKB01_001_05_A_SSFSE.npy
# The calculated volume is 6039.66 cm^3
# The actual volume is 5898.96 cm^3
# ---------------------------------------
# input_JKB01_001_05_B_SSFSE.npy
# The calculated volume is 5135.72 cm^3
# The actual volume is 4970.14 cm^3
# ---------------------------------------
# input_JKB01_001_05_C_SSFSE.npy
# The calculated volume is 5268.70 cm^3
# The actual volume is 5343.98 cm^3
# ---------------------------------------
# input_JKB01_001_06_A_SSFSE.npy
# The calculated volume is 5283.29 cm^3
# The actual volume is 5394.31 cm^3
# ---------------------------------------
# input_JKB01_001_06_B_SSFSE.npy
# The calculated volume is 4319.34 cm^3
# The actual volume is 4345.36 cm^3
# ---------------------------------------
# input_JKB01_001_06_C_SSFSE.npy
# The calculated volume is 3604.90 cm^3
# The actual volume is 3474.53 cm^3
# ---------------------------------------
# input_JKB01_001_07_A_SSFSE.npy
# The calculated volume is 3292.51 cm^3
# The actual volume is 3197.67 cm^3
# ---------------------------------------
# input_JKB01_001_07_B_SSFSE.npy
# The calculated volume is 3286.05 cm^3
# The actual volume is 3399.68 cm^3
# ---------------------------------------
# input_JKB01_001_07_C_SSFSE.npy
# The calculated volume is 3488.79 cm^3
# The actual volume is 3371.34 cm^3
# ---------------------------------------
# input_JKB01_001_08_A_SSFSE.npy
# The calculated volume is 3671.04 cm^3
# The actual volume is 3911.53 cm^3
# ---------------------------------------
# input_JKB01_001_08_B_SSFSE.npy
# The calculated volume is 4182.12 cm^3
# The actual volume is 4073.31 cm^3
# ---------------------------------------
# input_JKB01_001_10_A_SSFSE.npy
# The calculated volume is 4071.17 cm^3
# The actual volume is 3391.99 cm^3
# ---------------------------------------
# input_JKB01_001_10_C_SSFSE.npy
# The calculated volume is 4702.99 cm^3
# The actual volume is 3874.37 cm^3
# ---------------------------------------
# input_JKB01_001_13_A_SSFSE.npy
# The calculated volume is 4299.01 cm^3
# The actual volume is 4208.93 cm^3
# ---------------------------------------
# input_JKB01_001_13_B_SSFSE.npy
# The calculated volume is 4368.32 cm^3
# The actual volume is 4235.94 cm^3
# ---------------------------------------
# input_JKB01_001_13_C_SSFSE.npy
# The calculated volume is 4091.78 cm^3
# The actual volume is 4007.99 cm^3
# ---------------------------------------
# input_JKB01_001_15_A_SSFSE.npy
# The calculated volume is 3606.23 cm^3
# The actual volume is 3607.69 cm^3
# ---------------------------------------
# input_JKB01_001_16_A_SSFSE.npy
# The calculated volume is 3088.88 cm^3
# The actual volume is 3407.10 cm^3
# ---------------------------------------
# input_JKB01_001_16_B_SSFSE.npy
# The calculated volume is 3150.83 cm^3
# The actual volume is 3191.10 cm^3
# ---------------------------------------
# input_JKB01_001_16_C_SSFSE.npy
# The calculated volume is 3282.54 cm^3
# The actual volume is 3359.97 cm^3
# ---------------------------------------
# input_JKB01_001_17_A_SSFSE.npy
# The calculated volume is 4715.23 cm^3
# The actual volume is 5175.14 cm^3
# ---------------------------------------
# input_JKB01_001_17_B_SSFSE.npy
# The calculated volume is 4058.36 cm^3
# The actual volume is 4786.14 cm^3
# ---------------------------------------
# input_JKB01_001_17_C_SSFSE.npy
# The calculated volume is 4532.82 cm^3
# The actual volume is 4827.62 cm^3
# ---------------------------------------
# input_JKB01_001_20_A_SSFSE.npy
# The calculated volume is 2771.22 cm^3
# The actual volume is 2960.61 cm^3
# ---------------------------------------
# input_JKB01_001_20_B_SSFSE.npy
# The calculated volume is 2492.76 cm^3
# The actual volume is 2890.89 cm^3
# ---------------------------------------
# input_JKB01_001_20_C_SSFSE.npy
# The calculated volume is 2579.33 cm^3
# The actual volume is 2710.01 cm^3
# ---------------------------------------
# input_JKB01_001_21_A_SSFSE.npy
# The calculated volume is 7206.65 cm^3
# The actual volume is 6054.92 cm^3
# ---------------------------------------
# input_JKB01_001_21_B_SSFSE.npy
# The calculated volume is 6703.45 cm^3
# The actual volume is 5252.69 cm^3
# ---------------------------------------
# input_JKB01_001_21_C_SSFSE.npy
# The calculated volume is 6465.05 cm^3
# The actual volume is 4920.38 cm^3
# ---------------------------------------
# input_JKB01_001_24_A_SSFSE.npy
# The calculated volume is 4431.24 cm^3
# The actual volume is 4548.32 cm^3
# ---------------------------------------
# input_JKB01_001_24_B_SSFSE.npy
# The calculated volume is 3273.05 cm^3
# The actual volume is 3423.94 cm^3
# ---------------------------------------
# input_JKB01_001_24_C_SSFSE.npy
# The calculated volume is 3820.00 cm^3
# The actual volume is 3905.94 cm^3
# ---------------------------------------
# input_JKB01_001_26_A_SSFSE.npy
# The calculated volume is 4548.95 cm^3
# The actual volume is 4777.68 cm^3
# ---------------------------------------
# input_JKB01_001_26_B_SSFSE.npy
# The calculated volume is 4401.92 cm^3
# The actual volume is 4581.22 cm^3
# ---------------------------------------
# input_JKB01_001_26_C_SSFSE.npy
# The calculated volume is 5177.89 cm^3
# The actual volume is 5643.02 cm^3
# ---------------------------------------
# input_JKB01_001_27_A_SSFSE.npy
# The calculated volume is 4278.95 cm^3
# The actual volume is 4303.43 cm^3
# ---------------------------------------
# input_JKB01_001_27_B_SSFSE.npy
# The calculated volume is 4310.57 cm^3
# The actual volume is 4012.50 cm^3
# ---------------------------------------
# input_JKB01_001_27_C_SSFSE.npy
# The calculated volume is 4224.99 cm^3
# The actual volume is 4141.70 cm^3

# %%
x = [r[1] for r in results]
y = [r[0] for r in results]
plt.figure()
plt.plot(x,y,'ro')
plt.plot(np.arange(0,np.max(x)),np.arange(0,np.max(x)),'k--')
plt.xlim([0,np.max(x)])
plt.ylim([0,np.max(y)])
plt.ylabel('Calculated Volume (cc)')
plt.xlabel('Actual Volume (cc)')
plt.title("Correlation of Actual and Predicted Liver Volumes of Test Subjects")
plt.show()
cc = np.corrcoef(x,y)[0,1]
print('Correlation coefficient is {:.03f}'.format(cc))
# Out:
# Correlation coefficient is 0.931
